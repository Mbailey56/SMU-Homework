# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

import json
import seaborn as sns
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression
# Import API key
from api_keys import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 657

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities[0:10]
# Out:
# ['pinega',
#  'busselton',
#  'hermanus',
#  'albany',
#  'bredasdorp',
#  'illoqqortoormiut',
#  'tuktoyaktuk',
#  'saint-philippe',
#  'filingue',
#  'bluff']

# %%
rows = []

for city in cities:
    print()
    print(city)
    row = {}

    try:
    
        # get the geocode, lat and long
        url = f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={weather_api_key}"
        response = requests.get(url)

        if (response.status_code == 200):
            data = response.json()

            # parse data
            if (len(data) > 0):
                lat = data[0]["lat"]
                lon = data[0]["lon"]

                # make second request to get weather
                url2 = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={weather_api_key}&units=imperial'
                response2 = requests.get(url2)

                if (response2.status_code == 200):
                    data2 = response2.json()

                    # parse data
                    weather = data2["weather"][0]["main"]
                    temp = data2["main"]["temp"]
                    humid = data2["main"]["humidity"]
                    pressure = data2["main"]["pressure"]
                    wind = data2["wind"]["speed"]
                    clouds = data2["clouds"]["all"]
                else:
                    print(f"Weather request failed for {city}")
                    weather = None
                    temp = np.nan
                    humid = np.nan
                    pressure = np.nan
                    wind = np.nan

                # put into flat dictionary
                row["city"] = city
                row["latitude"] = lat
                row["longitude"] = lon
                row["weather"] = weather
                row["temperature"] = temp
                row["humidity"] = humid
                row["pressure"] = pressure
                row["wind_speed"] = wind
                row["cloudiness"] = clouds

                # append to list
                rows.append(row)

            else:
                print(f"no lat/long for {city}")
                pass
        else:
            print(f"failed request for geocode for {city}")
            pass
    except Exception as e:
        print(e)
        print(f"Oh no! Everything failed and broke for {city}. There should be an error above. Sux")
        print()
        
    # sleep
    time.sleep(3)
# Out:
# pinega
#
# busselton
#
# hermanus
#
# albany
#
# bredasdorp
#
# illoqqortoormiut
#
# tuktoyaktuk
#
# saint-philippe
#
# filingue
#
# bluff
#
# komsomolskiy
#
# ushuaia
#
# carnarvon
#
# esperance
#
# yuanping
#
# wasilla
#
# new norfolk
#
# cherskiy
# no lat/long for cherskiy
#
# narsaq
#
# metehara
# no lat/long for metehara
#
# port blair
#
# dikson
#
# kollumerland
# no lat/long for kollumerland
#
# yellowknife
#
# victoria
#
# cape town
#
# waterloo
#
# barrow
#
# georgetown
#
# airai
#
# cabo san lucas
#
# hambantota
#
# cassilandia
#
# potchefstroom
#
# saint george
#
# mataura
#
# ossora
#
# kapaa
#
# baramati
#
# bambous virieux
#
# butaritari
#
# umm lajj
#
# rikitea
#
# sisimiut
#
# jamestown
#
# avarua
#
# punta arenas
#
# mar del plata
#
# san cristobal
#
# tomelloso
#
# brae
#
# hofn
#
# bethel
#
# akyab
#
# sentyabrskiy
# no lat/long for sentyabrskiy
#
# tumannyy
# no lat/long for tumannyy
#
# jiddah
#
# ahipara
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Oh no! Everything failed and broke for ahipara. There should be an error above. Sux
#
#
# emerald
#
# sosnovo-ozerskoye
#
# pisco
#
# senador jose porfirio
#
# port alfred
#
# bud
#
# kahului
#
# katsuura
#
# puerto ayora
#
# ilulissat
#
# norman wells
#
# inta
#
# carauari
#
# abha
#
# ribeira grande
#
# flin flon
#
# wamba
#
# lompoc
#
# tsihombe
#
# najran
#
# carballo
#
# torbay
#
# upernavik
#
# vila franca do campo
#
# padang
#
# dolores
#
# ruatoria
#
# broome
#
# doha
#
# xuddur
#
# dodge city
#
# sao joao da barra
#
# grand river south east
#
# kavieng
#
# saskylakh
#
# marsh harbour
#
# severo-kurilsk
#
# hobart
#
# aljezur
#
# tessalit
#
# baoding
#
# miraflores
#
# hengyang
#
# port elizabeth
#
# zhuhai
#
# buala
#
# samusu
#
# celendin
#
# altoona
#
# taolanaro
# no lat/long for taolanaro
#
# alice springs
#
# catamarca
#
# san patricio
#
# kaitangata
#
# nola
#
# marang
#
# dakar
#
# sabha
#
# barentsburg
#
# tiruchchendur
#
# vaini
#
# xai-xai
#
# kirkwood
#
# manono
#
# sakassou
#
# ulaanbaatar
#
# aiquile
#
# nikolskoye
#
# east london
#
# puerto narino
#
# lorengau
#
# hithadhoo
#
# noumea
#
# laguna
#
# port moresby
#
# okoneshnikovo
#
# methven
#
# aykhal
#
# suoyarvi
#
# andevoranto
# no lat/long for andevoranto
#
# sao jose do belmonte
#
# luderitz
#
# loukhi
#
# fort nelson
#
# amealco
#
# onega
#
# petropavlovsk-kamchatskiy
#
# villazon
#
# anchorage
#
# porto novo
#
# saint-raymond
#
# biharamulo
#
# vardo
#
# saldanha
#
# halifax
#
# craig
#
# faanui
#
# amapa
#
# kamenka
#
# lexington
#
# vestmannaeyjar
#
# ixtapa
#
# hilo
#
# moerai
#
# henties bay
#
# asosa
#
# pevek
#
# fallon
#
# talnakh
#
# copiapo
#
# bealanana
#
# pimenteiras
#
# bonfim
#
# snasa
#
# carahue
#
# vigrestad
#
# barsovo
#
# nome
#
# kyabram
#
# banes
#
# nuuk
#
# cruzilia
#
# port-gentil
#
# jujuy
#
# abashiri
#
# mahebourg
#
# hit
#
# jinka
#
# lebu
#
# puerto escondido
#
# atuona
#
# vila velha
#
# krasnoselkup
#
# katherine
#
# khatanga
#
# turukhansk
#
# mount isa
#
# poum
#
# salinas
#
# vaitupu
#
# faya
#
# zambezi
#
# denpasar
#
# lagoa
#
# sao joaquim
#
# chimbarongo
#
# nizhneyansk
#
# kerewan
#
# general roca
#
# suntar
#
# saleaula
# no lat/long for saleaula
#
# chlorakas
#
# dawlatabad
#
# nizhniy baskunchak
# no lat/long for nizhniy baskunchak
#
# mogapi
#
# tondi
#
# kiunga
#
# jimani
#
# muros
#
# dickinson
#
# lesnoy
#
# te anau
#
# port macquarie
#
# fairbanks
#
# moron
#
# siguiri
#
# belushya guba
#
# phuntsholing
#
# sayyan
#
# ambon
#
# tiksi
#
# kupang
#
# volksrust
#
# cabedelo
#
# sabla
#
# namibe
#
# san ramon
#
# eureka
#
# nguiu
#
# libenge
#
# amderma
#
# ucluelet
#
# saint-francois
#
# itoman
#
# marystown
#
# nemuro
#
# cervo
#
# asyut
#
# rawson
#
# conde
#
# flinders
#
# charlottetown
#
# matucana
#
# srednekolymsk
#
# kintampo
#
# thompson
#
# jiayuguan
#
# fortuna
#
# chernyshevskiy
#
# leningradskiy
#
# bitung
#
# port lincoln
#
# taybad
#
# edd
#
# almas
#
# alofi
#
# ambulu
#
# quthing
#
# maniitsoq
#
# gamboma
#
# poya
#
# kloulklubed
#
# souillac
#
# malanje
#
# tuatapere
#
# tilichiki
#
# antsohihy
#
# imeni poliny osipenko
#
# plettenberg bay
#
# piacabucu
#
# pingliang
#
# inhambane
#
# klaksvik
#
# mulchen
#
# chinhoyi
#
# kodiak
#
# saint-joseph
#
# attawapiskat
#
# walvis bay
#
# cidreira
#
# kenai
#
# roma
#
# mana
#
# codrington
#
# meulaboh
#
# malwan
#
# kaputa
#
# wewak
#
# aksu
#
# abancay
#
# raton
#
# seryshevo
# no lat/long for seryshevo
#
# kartuzy
#
# isangel
#
# mehamn
#
# qaanaaq
#
# broken hill
#
# sorong
#
# kangaatsiaq
#
# guane
#
# zhanatas
#
# amuntai
#
# comodoro rivadavia
#
# chuy
#
# shimoda
#
# etchojoa
#
# port-cartier
#
# tabou
#
# cascas
#
# arraial do cabo
#
# shingu
#
# dubuque
#
# vostok
#
# labuhan
#
# udachnyy
#
# cerritos
#
# chippewa falls
#
# birin
#
# college
#
# iqaluit
#
# sarai mir
#
# san vicente
#
# tasiilaq
#
# mangrol
#
# khonuu
#
# lundin links
#
# landang
#
# owando
#
# port shepstone
#
# datong
#
# ziarat
#
# kruisfontein
#
# victor harbor
#
# mayya
#
# swan hill
#
# porto santo
#
# okhotsk
#
# warendorf
#
# pinkafeld
#
# vao
#
# olafsvik
#
# longyearbyen
#
# kununurra
#
# muhos
#
# quelimane
#
# cairns
#
# san quintin
#
# paragominas
#
# husavik
#
# coos bay
#
# hami
#
# miramar
#
# babstovo
#
# kamenskoye
#
# karauzyak
# no lat/long for karauzyak
#
# botwood
#
# bosaso
#
# itarema
#
# vanimo
#
# kang
#
# godda
#
# foca
#
# karangasem
#
# urambo
#
# clyde river
#
# tutoia
#
# grindavik
#
# nguruka
#
# castro
#
# rabo de peixe
#
# severnyy
#
# sao jose da coroa grande
#
# kimbe
#
# hurghada
#
# ust-kan
#
# dharchula
#
# mecca
#
# front royal
#
# olinda
#
# rocha
#
# sidi bu zayd
# no lat/long for sidi bu zayd
#
# polunochnoye
#
# la ronge
#
# waddan
#
# marcona
#
# sabya
#
# trairi
#
# svetlogorsk
#
# gat
#
# rakiv lis
#
# beringovskiy
# no lat/long for beringovskiy
#
# bagotville
#
# iisalmi
#
# half moon bay
#
# namatanai
#
# port hawkesbury
#
# pathein
#
# vozhd proletariata
# no lat/long for vozhd proletariata
#
# guarapari
#
# fort saint john
# no lat/long for fort saint john
#
# haines junction
#
# dwarka
#
# ukiah
#
# sishui
#
# slave lake
#
# avera
#
# mundargi
#
# lasa
#
# borna
#
# bardiyah
# no lat/long for bardiyah
#
# kemijarvi
#
# belaya gora
#
# yanan
#
# jabiru
#
# peniche
#
# huanan
#
# opunake
#
# andra
#
# saint anthony
#
# ndele
#
# bolgatanga
#
# lolua
# no lat/long for lolua
#
# verkhoyansk
#
# nchelenge
#
# palauig
#
# avanigadda
#
# paita
#
# adrar
#
# tungkang
# no lat/long for tungkang
#
# jiwani
#
# solnechnyy
#
# fernley
#
# moose factory
#
# zhigansk
#
# constitucion
#
# bengkulu
#
# garissa
#
# yar-sale
# no lat/long for yar-sale
#
# chokurdakh
#
# baker city
#
# ostrovnoy
#
# elk
#
# calatayud
#
# maghama
#
# palu
#
# mys shmidta
#
# petauke
#
# waounde
#
# koslan
#
# mount gambier
#
# newport
#
# acapulco
#
# bushehr
#
# ancud
#
# panjakent
#
# kavaratti
#
# aldan
#
# mayskiy
#
# provideniya
#
# ust-kuyga
#
# atherton
#
# katsiveli
#
# pangnirtung
#
# waingapu
#
# borogontsy
#
# kobojango
# no lat/long for kobojango
#
# alamosa
#
# nezhinka
# no lat/long for nezhinka
#
# smithers
#
# marv dasht
# no lat/long for marv dasht
#
# toliary
# no lat/long for toliary
#
# wisconsin rapids
#
# port hedland
#
# yamachiche
#
# kieta
#
# mahibadhoo
#
# hollola
#
# hobyo
#
# ponta do sol
#
# hasaki
#
# kaeo
#
# zhanakorgan
#
# puerto ayacucho
#
# gornopravdinsk
#
# omboue
#
# bathsheba
#
# pishva
#
# tautira
#
# portland
#
# kitami
#
# shache
# no lat/long for shache
#
# banda aceh
#
# birjand
#
# naze
#
# macau
#
# saint-pierre
#
# shelburne
#
# roald
#
# ratodero
#
# vanavara
#
# zemio
#
# mon
#
# touros
#
# virgilio
#
# priiskovyy
# no lat/long for priiskovyy
#
# antofagasta
#
# aswan
#
# praia
#
# aleppo
#
# sabang
#
# xadani
#
# tawkar
#
# richards bay
#
# marfino
#
# manacapuru
#
# churapcha
#
# kudahuvadhoo
#
# christchurch
#
# antissa
#
# xining
#
# neuquen
#
# kaoma
#
# dinar
#
# hermagor
#
# shenandoah
#
# viedma
#
# salalah
#
# quatre cocos
#
# carlisle
#
# robertsport
#
# normandin
#
# auki
#
# guaymas
#
# passo de camaragibe
#
# utiroa
#
# juba
#
# meadow lake
#
# rosarito
#
# karratha
#
# hare bay
#
# hirara
#
# jiexiu
#
# tocopilla
#
# sungurlu
#
# patur
#
# punta de piedra
#
# bahir dar
#
# khani
#
# coihaique
#
# buraydah
#
# gazni
#
# ekhabi
#
# ust-nera
#
# klyuchi
#
# geraldton
#
# franca
#
# lamar
#
# krutinka
#
# russell
#
# caravelas
#
# chicama
#
# pitsunda
#
# herat
#
# kabinda
#
# brainerd
#
# soller
#
# ranong
#
# melbu
#
# majene
#
# kenora
#
# guayaramerin
#
# trat
#
# ulaangom
#
# gorin
#
# zhongshu
#
# gopalpur
#
# takoradi
#
# port arthur
#
# saint simons
#
# vrangel
#
# coquimbo
#
# khandyga
#
# novovasylivka
#
# aklavik
#
# bay roberts
#
# seoul
#
# yarim
#
# iquique
#
# yenagoa
#
# andros town
#
# kapiri mposhi
#
# tres arroyos
#
# sioux lookout
#
# falealupo
#
# barranca
#
# troitsko-pechorsk
#
# tura
#
# hamilton
#
# pemba
#
# talaya
#
# mackay
#
# andrushivka
#
# goycay
#
# palmer
#
# kungsbacka
#
# chunskiy
#
# zunyi
#
# la reforma
#
# dingle
#
# yuancheng
#
# bunga
#
# grand gaube
#
# saint-ambroise
#
# wanlaweyn
#
# roebourne
#
# kirakira
#
# usvyaty
# no lat/long for usvyaty
#
# kidal
#
# ulan-ude
#
# ondorhaan
#
# tarauaca
#
# griffith
#
# gao
#
# komsomolets
#
# guangyuan
#
# pemangkat
#
# san carlos de bariloche
#
# aktash
#
# atambua
#
# beira
#
# beppu
#
# phan thiet
#
# paradwip
# no lat/long for paradwip
#
# santa cruz
#
# marzuq
#
# samarai
#
# okha
#
# pochutla
#
# havoysund
#
# bulungu
#
# lar gerd
# no lat/long for lar gerd
#
# gamba
#
# alihe
#
# butembo
#
# alyangula
#
# tignere
#
# chapais
#
# ornskoldsvik
#
# mikkeli

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(rows)
df.head()
# Out:
#          city   latitude   longitude weather  temperature  humidity  pressure  \
# 0      pinega  64.697281   43.392376  Clouds        21.24        93      1001
# 1   busselton -33.644499  115.348875  Clouds        73.47        42      1014
# 2    hermanus -34.417500   19.236111  Clouds        65.84        85      1016
# 3      albany  42.651167  -73.754968  Clouds        51.42        95      1006
# 4  bredasdorp -34.533055   20.042778   Clear        62.82        92      1017
#
#    wind_speed  cloudiness
# 0       12.77         100
# 1        8.30          35
# 2       14.41          14
# 3        1.99         100
# 4        8.25           9

# %%
df.to_csv(output_data_file, index=False)

# %%
df = pd.read_csv(output_data_file)
df.head()
# Out:
#          city   latitude   longitude weather  temperature  humidity  pressure  \
# 0      pinega  64.697281   43.392376  Clouds        21.24        93      1001
# 1   busselton -33.644499  115.348875  Clouds        73.47        42      1014
# 2    hermanus -34.417500   19.236111  Clouds        65.84        85      1016
# 3      albany  42.651167  -73.754968  Clouds        51.42        95      1006
# 4  bredasdorp -34.533055   20.042778   Clear        62.82        92      1017
#
#    wind_speed  cloudiness
# 0       12.77         100
# 1        8.30          35
# 2       14.41          14
# 3        1.99         100
# 4        8.25           9

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
mask = df.humidity > 100
df.loc[mask]
# Out:
# Empty DataFrame
# Columns: [city, latitude, longitude, weather, temperature, humidity, pressure, wind_speed, cloudiness]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.latitude, df.temperature)
plt.title("Latitude vs Temperature -12/31/22022")
plt.xlabel('latitude')
plt.ylabel('temperature (F)')
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.latitude, df.humidity)
plt.title("Latitude vs Humidity -12/31/22022")
plt.xlabel('latitude')
plt.ylabel('Humidity %')
plt.grid(True)
plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.latitude, df.cloudiness)
plt.title("Latitude vs Cloudiness -12/31/22022")
plt.xlabel('latitude')
plt.ylabel('Cloudiness %')
plt.grid(True)
plt.savefig("output_data/Fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.latitude, df.wind_speed)
plt.title("Latitude vs Wind Speed -12/31/22022")
plt.xlabel('latitude')
plt.ylabel('Wind Speed')
plt.grid(True)
plt.savefig("output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude > 0].reset_index(drop=True)


x_values = df2['latitude']
y_values = df2['temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,0),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6596293249395908

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude < 0].reset_index(drop=True)

# Print out the r-squared value along with the plot.
x_values = df2['latitude']
y_values = df2['temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,100),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08785419008065558

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude > 0].reset_index(drop=True)

# Print out the r-squared value along with the plot.
x_values = df2['latitude']
y_values = df2['humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-0,100),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.21557936988856732

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude < 0].reset_index(drop=True)

# Print out the r-squared value along with the plot.
x_values = df2['latitude']
y_values = df2['humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,100),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.12722890000145312

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude > 0].reset_index(drop=True)

# Print out the r-squared value along with the plot.
x_values = df2['latitude']
y_values = df2['cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.12319285543401658

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude > 0].reset_index(drop=True)

# Print out the r-squared value along with the plot.
x_values = df2['latitude']
y_values = df2['cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.12319285543401658

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude < 0].reset_index(drop=True)

# Print out the r-squared value along with the plot.
x_values = df2['latitude']
y_values = df2['wind_speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09218079076692472

# %%
There is a small positive relationship between latitude and Wind Speed.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
df2 = df.loc[df.latitude > 0].reset_index(drop=True)

# Print out the r-squared value along with the plot.
x_values = df2['latitude']
y_values = df2['wind_speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.xlabel('latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.025167267128494118

# %%
No relationship between latitude and wind speed
